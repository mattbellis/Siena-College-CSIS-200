# %%
# Code example

# %%
# Cell memory.

# %% [markdown]
# Markdown example

# %% [markdown]
# <a href="https://help.github.com/articles/markdown-basics/">Markdown basics</a>.
#
# <a href="https://help.github.com/articles/github-flavored-markdown/">Github flavoured Markdown</a>.

# %%
# More sweet Python code.

# %%
# Check out the help notes!

# %% [markdown]
# You can find more information about Jupyter in the <a href="https://github.com/mattbellis/Siena-College-CSIS-200/blob/master/RESOURCES.md">RESOURSES</a> link on our class website.
